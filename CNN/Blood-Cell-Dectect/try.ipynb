# %%
import matplotlib.pyplot as plt

from chainercv.datasets import voc_bbox_label_names
from chainercv.links import SSD300
from chainercv.utils import read_image
from chainercv.visualizations import vis_bbox

# %%
# Read an RGB image and return it in CHW format.
img = read_image('sample.jpg')
model = SSD300(pretrained_model='voc0712')
bboxes, labels, scores = model.predict([img])
vis_bbox(img, bboxes[0], labels[0], scores[0],
         label_names=voc_bbox_label_names)
plt.show()
# Out:
# Downloading ...
# From: https://chainercv-models.preferred.jp/ssd300_voc0712_converted_2017_06_06.npz
# To: /home/nanguage/.chainer/dataset/_dl_cache/7580b6888d3f7742a1b531234009c0b0
#   %   Total    Recv       Speed  Time left
# 100   93MiB   93MiB   1642KiB/s    0:00:00

# %%
from chainercv.visualizations import vis_bbox
import numpy as np

img = np.zeros((3, 224, 224), dtype=np.float32)
# We call a variable/array of bounding boxes as `bbox` throughout the library
bbox = np.array([[10, 10, 20, 40], [150, 150, 200, 200]], dtype=np.float32)

vis_bbox(img, bbox)
plt.show()

# %%
from chainercv.datasets import VOCBboxDataset
from chainercv.datasets import voc_bbox_label_names
from chainercv.visualizations import vis_bbox

dataset = VOCBboxDataset(year='2012')
img, bbox, label = dataset[0]
print(bbox.shape)  # (2, 4)
print(label.shape)  # (2,)
vis_bbox(img, bbox, label, label_names=voc_bbox_label_names)
plt.show()
# Out:
# Downloading ...
# From: http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# To: /home/nanguage/.chainer/dataset/_dl_cache/92029705a99338d0932803388148a725
#   %   Total    Recv       Speed  Time left
#  44 1907MiB  842MiB   2287KiB/s    0:07:56
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  51 1907MiB  966MiB   2427KiB/s    0:06:37
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 100 1907MiB 1907MiB   2314KiB/s    0:00:00(2, 4)
# (2,)

# %%
train_data = VOCBboxDataset(split='trainval', year='2007')
# Out:
# Downloading ...
# From: http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# To: /home/nanguage/.chainer/dataset/_dl_cache/1b8e6e3f7ee4cdd7960310d1b25d2f4c
#   %   Total    Recv       Speed  Time left
# 100  439MiB  439MiB   1687KiB/s    0:00:00

# %%
img, bbox, label = train_data[0]
print(bbox.shape)  # (2, 4)
print(label.shape)  # (2,)
vis_bbox(img, bbox, label, label_names=voc_bbox_label_names)
plt.show()
# Out:
# (3, 4)
# (3,)

# %%
img.shape
# Out:
# (3, 375, 500)

# %%
from chainercv.datasets import voc_bbox_label_names

# %%
voc_bbox_label_names
# Out:
# ('aeroplane',
#  'bicycle',
#  'bird',
#  'boat',
#  'bottle',
#  'bus',
#  'car',
#  'cat',
#  'chair',
#  'cow',
#  'diningtable',
#  'dog',
#  'horse',
#  'motorbike',
#  'person',
#  'pottedplant',
#  'sheep',
#  'sofa',
#  'train',
#  'tvmonitor')

# %%
train_data = VOCBboxDataset(data_dir="./data/BCCD/", split="train")

# %%
train_data._get_annotations(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-33943521cc83> in <module>()
# ----> 1 train_data._get_annotations(1)
#
# ~/S/miniconda3/lib/python3.6/site-packages/chainercv/datasets/voc/voc_bbox_dataset.py in _get_annotations(self, i)
#     108                 for tag in ('ymin', 'xmin', 'ymax', 'xmax')])
#     109             name = obj.find('name').text.lower().strip()
# --> 110             label.append(voc_utils.voc_bbox_label_names.index(name))
#     111         bbox = np.stack(bbox).astype(np.float32)
#     112         label = np.stack(label).astype(np.int32)
#
# ValueError: tuple.index(x): x not in tuple
